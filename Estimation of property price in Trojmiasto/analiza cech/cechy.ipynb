# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### gratka - domy, mieszkania / miasta

# %%
pd_gratka_domy_gdansk = pd.read_json('../dysk/dane z portali/gratka/gratkapl_domy_gdansk.json')
pd_gratka_domy_gdynia = pd.read_json('../dysk/dane z portali/gratka/gratkapl_domy_gdynia.json')
pd_gratka_domy_sopot = pd.read_json('../dysk/dane z portali/gratka/gratkapl_domy_sopot.json')

# %%
pd_gratka_mieszkania_gdansk = pd.read_json('../dysk/dane z portali/gratka/gratkapl_mieszkania_gdansk.json')
pd_gratka_mieszkania_gdynia = pd.read_json('../dysk/dane z portali/gratka/gratkapl_mieszkania_gdynia.json')
pd_gratka_mieszkania_sopot = pd.read_json('../dysk/dane z portali/gratka/gratkapl_mieszkania_sopot.json')

# %% [markdown]
# ### morizon

# %%
pd_morizon_gdansk = pd.read_json('../dysk/dane z portali/morizon/data_gdansk.json', orient='index')
pd_morizon_gdynia = pd.read_json('../dysk/dane z portali/morizon/data_gdynia.json', orient='index')
pd_morizon_sopot = pd.read_json('../dysk/dane z portali/morizon/data_sopot.json', orient='index')

# %% [markdown]
# ### otodom

# %%
pd_otodom_domy = pd.read_json('../dysk/dane z portali/otodom/data_otodom_domy.json', orient='index')
pd_otodom_mieszkania = pd.read_json('../dysk/dane z portali/otodom/data_otodom_mieszkania.json', orient='index')

# %% [markdown]
# ### trojmiasto

# %%
pd_trojmiasto = pd.read_json('../dysk/dane z portali/trojmiasto/trojmiasto_domy_mieszkania_wtorny_i_pierwotny.json')

# %% [markdown]
# ## lista utworzonych df z liczbą kolumn (cech) wliczająć id

# %%
# %whos DataFrame
# Out:
# Variable                      Type         Data/Info
# ----------------------------------------------------
# pd_gratka_domy_gdansk         DataFrame                             <...>\n[303 rows x 45 columns]
# pd_gratka_domy_gdynia         DataFrame                             <...>\n[210 rows x 39 columns]
# pd_gratka_domy_sopot          DataFrame                             <...>n\n[42 rows x 37 columns]
# pd_gratka_mieszkania_gdansk   DataFrame                             <...>n[2594 rows x 48 columns]
# pd_gratka_mieszkania_gdynia   DataFrame                             <...>n[1020 rows x 48 columns]
# pd_gratka_mieszkania_sopot    DataFrame                             <...>\n[365 rows x 45 columns]
# pd_morizon_gdansk             DataFrame            cena     miasto  <...>n[3398 rows x 51 columns]
# pd_morizon_gdynia             DataFrame             cena            <...>n[1516 rows x 50 columns]
# pd_morizon_sopot              DataFrame            cena miasto    dz<...>\n[537 rows x 43 columns]
# pd_otodom_domy                DataFrame                             <...>\n[970 rows x 72 columns]
# pd_otodom_mieszkania          DataFrame                             <...>n[8513 rows x 53 columns]
# pd_trojmiasto                 DataFrame                             <...>[15529 rows x 26 columns]

# %% [markdown]
# ### dowiedziałem się, że mam zająć się tylko mieszkaniami więc usuwam df związane bezpośrednio z domami

# %%
import gc

# %%
del pd_gratka_domy_gdansk,pd_gratka_domy_gdynia,pd_gratka_domy_sopot,pd_otodom_domy
gc.collect()
# Out:
# 40

# %%
# %whos DataFrame
# Out:
# Variable                      Type         Data/Info
# ----------------------------------------------------
# pd_gratka_mieszkania_gdansk   DataFrame                             <...>n[2594 rows x 48 columns]
# pd_gratka_mieszkania_gdynia   DataFrame                             <...>n[1020 rows x 48 columns]
# pd_gratka_mieszkania_sopot    DataFrame                             <...>\n[365 rows x 45 columns]
# pd_morizon_gdansk             DataFrame            cena     miasto  <...>n[3398 rows x 51 columns]
# pd_morizon_gdynia             DataFrame             cena            <...>n[1516 rows x 50 columns]
# pd_morizon_sopot              DataFrame            cena miasto    dz<...>\n[537 rows x 43 columns]
# pd_otodom_mieszkania          DataFrame                             <...>n[8513 rows x 53 columns]
# pd_trojmiasto                 DataFrame                             <...>[15529 rows x 26 columns]

# %%
dataframe_list = %who_ls DataFrame
dataframe_list
# Out:
# ['pd_gratka_mieszkania_gdansk',
#  'pd_gratka_mieszkania_gdynia',
#  'pd_gratka_mieszkania_sopot',
#  'pd_morizon_gdansk',
#  'pd_morizon_gdynia',
#  'pd_morizon_sopot',
#  'pd_otodom_mieszkania',
#  'pd_trojmiasto']

# %%
df_porownanie = pd.DataFrame(columns = dataframe_list) 
df_porownanie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   pd_gratka_mieszkania_gdansk  0 non-null      object
#  1   pd_gratka_mieszkania_gdynia  0 non-null      object
#  2   pd_gratka_mieszkania_sopot   0 non-null      object
#  3   pd_morizon_gdansk            0 non-null      object
#  4   pd_morizon_gdynia            0 non-null      object
#  5   pd_morizon_sopot             0 non-null      object
#  6   pd_otodom_mieszkania         0 non-null      object
#  7   pd_trojmiasto                0 non-null      object
# dtypes: object(8)
# memory usage: 0.0+ bytes

# %%
df_porownanie['pd_morizon_gdansk'] = pd_morizon_gdansk.columns[1:]

df_porownanie['pd_gratka_mieszkania_gdansk'] = pd.Series(pd_gratka_mieszkania_gdansk.columns[1:])
df_porownanie['pd_gratka_mieszkania_gdynia'] = pd.Series(pd_gratka_mieszkania_gdynia.columns[1:])
df_porownanie['pd_gratka_mieszkania_sopot'] = pd.Series(pd_gratka_mieszkania_sopot.columns[1:])
df_porownanie['pd_morizon_gdynia'] = pd.Series(pd_morizon_gdynia.columns[1:])
df_porownanie['pd_morizon_sopot'] = pd.Series(pd_morizon_sopot.columns[1:])
df_porownanie['pd_otodom_mieszkania'] = pd.Series(pd_otodom_mieszkania.columns[1:])
df_porownanie['pd_trojmiasto'] = pd.Series(pd_trojmiasto.columns[1:])

# %%
df_porownanie = df_porownanie.fillna(0)

# %%
df_porownanie
# Out:
#             pd_gratka_mieszkania_gdansk          pd_gratka_mieszkania_gdynia  \
# 0                                  cena                                 cena
# 1                           cena_waluta                          cena_waluta
# 2                          cena_za_metr                         cena_za_metr
# 3                         id_ogloszenia                        id_ogloszenia
# 4                                 tresc                                tresc
# 5                               zdjecie                              zdjecie
# 6                           lokalizacja                          lokalizacja
# 7                                 adres                                adres
# 8                     powierzchnia-w-m2  oplaty-czynsz-administracyjny-media
# 9                          powierzchnia                    powierzchnia-w-m2
# 10                         liczba-pokoi                         powierzchnia
# 11                         liczba_pokoi                         liczba-pokoi
# 12                               pietro                         liczba_pokoi
# 13                      forma-wlasnosci                               pietro
# 14                         typ-zabudowy                      forma-wlasnosci
# 15                      rodzaj_zabudowy                                 stan
# 16                             typ_domu                          wykonczenie
# 17                     material-budynku                           rok-budowy
# 18              liczba-pieter-w-budynku                           rok_budowy
# 19                liczba_pieter_budynku                         typ-zabudowy
# 20                   miejsce-parkingowe                      rodzaj_zabudowy
# 21                         forma-kuchni                             typ_domu
# 22                              kuchnia                     material-budynku
# 23                                 okna              liczba-pieter-w-budynku
# 24                     nazwa-inwestycji                liczba_pieter_budynku
# 25                   numer-referencyjny                   miejsce-parkingowe
# 26           forma-wyposazenie-lazienki           liczba-miejsc-parkingowych
# 27    usytuowanie-wzgledem-stron-swiata                      stan-instalacji
# 28                    data_aktualizacji                         forma-kuchni
# 29                    typ_nieruchomosci                              kuchnia
# 30  oplaty-czynsz-administracyjny-media                        stan-lazienki
# 31                           rok-budowy                                 okna
# 32                           rok_budowy                             glosnosc
# 33                                 stan                        dostepnosc-od
# 34                          wykonczenie                        data_dostepne
# 35           liczba-miejsc-parkingowych           czy-mieszkanie-ma-lazienke
# 36                      stan-instalacji           forma-wyposazenie-lazienki
# 37                        stan-lazienki               powierzchnia-dodatkowa
# 38                             glosnosc    usytuowanie-wzgledem-stron-swiata
# 39                        dostepnosc-od                          komunikacja
# 40                        data_dostepne                      zdrowie-i-uroda
# 41           czy-mieszkanie-ma-lazienke                             edukacja
# 42               powierzchnia-dodatkowa                            pozostale
# 43                          komunikacja                    data_aktualizacji
# 44                      zdrowie-i-uroda                    typ_nieruchomosci
# 45                             edukacja                   numer-referencyjny
# 46                            pozostale                     nazwa-inwestycji
# 47                                    0                                    0
# 48                                    0                                    0
# 49                                    0                                    0
#
#              pd_gratka_mieszkania_sopot                 pd_morizon_gdansk  \
# 0                                  cena                            miasto
# 1                           cena_waluta                         dzielnica
# 2                          cena_za_metr                             ulica
# 3                         id_ogloszenia                      powierzchnia
# 4                                 tresc                           cena_m2
# 5                               zdjecie                            pokoje
# 6                           lokalizacja             powierzchnia-uzytkowa
# 7                                 adres                            pietro
# 8                     powierzchnia-w-m2                     liczba-pieter
# 9                          powierzchnia                        typ-kuchni
# 10                         liczba-pokoi                            balkon
# 11                         liczba_pokoi              powierzchnia-balkonu
# 12                               pietro                             taras
# 13                      forma-wlasnosci                             rynek
# 14                           rok-budowy                       dostepne-od
# 15                           rok_budowy                   forma-wlasnosci
# 16                         typ-zabudowy                          na-biuro
# 17                      rodzaj_zabudowy                            kredyt
# 18                             typ_domu                      numer-oferty
# 19              liczba-pieter-w-budynku                    zaktualizowano
# 20                liczba_pieter_budynku                      opublikowano
# 21                   miejsce-parkingowe                        rok-budowy
# 22                   numer-referencyjny                      stan-budynku
# 23                    data_aktualizacji                             tresc
# 24                    typ_nieruchomosci                         deweloper
# 25                     material-budynku                        inwestycja
# 26                         forma-kuchni                stan-nieruchomosci
# 27                              kuchnia                   liczba-lazienek
# 28  oplaty-czynsz-administracyjny-media                       typ-budynku
# 29                          komunikacja                  wysokosc-wnetrza
# 30                      zdrowie-i-uroda        liczba-poziomow-mieszkania
# 31                             edukacja                 czy-lazienka-z-wc
# 32                            pozostale                cena-do-negocjacji
# 33                                 stan                material-budowlany
# 34                          wykonczenie                   liczba-sypialni
# 35               powierzchnia-dodatkowa                            loggia
# 36                                 okna                      rodzaj-umowy
# 37                      stan-instalacji             powierzchnia-lazienki
# 38                        stan-lazienki              powierzchnia-ogrodka
# 39                             glosnosc                        na-zamiane
# 40           forma-wyposazenie-lazienki                  stolarka-okienna
# 41                     nazwa-inwestycji  czy-przy-mieszkaniu-jest-ogrodek
# 42    usytuowanie-wzgledem-stron-swiata                          typ-domu
# 43           czy-mieszkanie-ma-lazienke                  dodatkowe-koszty
# 44                                    0               powierzchnia-loggii
# 45                                    0                       lokalizacja
# 46                                    0               powierzchnia-tarasu
# 47                                    0                              dach
# 48                                    0                       pow-dzialki
# 49                                    0                 typ-nieruchomosci
#
#                    pd_morizon_gdynia            pd_morizon_sopot  \
# 0                             miasto                      miasto
# 1                          dzielnica                   dzielnica
# 2                              ulica                       ulica
# 3                       powierzchnia                powierzchnia
# 4                            cena_m2                     cena_m2
# 5                             pokoje                      pokoje
# 6              powierzchnia-uzytkowa       powierzchnia-uzytkowa
# 7                             pietro                      pietro
# 8                      liczba-pieter               liczba-pieter
# 9                         typ-kuchni  liczba-poziomow-mieszkania
# 10                 czy-lazienka-z-wc                      balkon
# 11                            balkon                       rynek
# 12              powierzchnia-balkonu                 dostepne-od
# 13                             taras                      kredyt
# 14                             rynek                numer-oferty
# 15                   forma-wlasnosci              zaktualizowano
# 16                          na-biuro                opublikowano
# 17                            kredyt                  rok-budowy
# 18                      numer-oferty                       tresc
# 19                    zaktualizowano             liczba-sypialni
# 20                      opublikowano                       taras
# 21                        rok-budowy                rodzaj-umowy
# 22                      stan-budynku            wysokosc-wnetrza
# 23                             tresc                  typ-kuchni
# 24        liczba-poziomow-mieszkania             liczba-lazienek
# 25                   liczba-sypialni       powierzchnia-lazienki
# 26                       dostepne-od           czy-lazienka-z-wc
# 27                       typ-budynku        powierzchnia-balkonu
# 28                material-budowlany             forma-wlasnosci
# 29                      rodzaj-umowy                 typ-budynku
# 30                stan-nieruchomosci          material-budowlany
# 31                  stolarka-okienna                stan-budynku
# 32  czy-przy-mieszkaniu-jest-ogrodek                    na-biuro
# 33                cena-do-negocjacji          stan-nieruchomosci
# 34                  wysokosc-wnetrza          cena-do-negocjacji
# 35                   liczba-lazienek            dodatkowe-koszty
# 36             powierzchnia-lazienki           typ-nieruchomosci
# 37                        na-zamiane                    typ-domu
# 38                         deweloper                        dach
# 39                        inwestycja            stolarka-okienna
# 40               powierzchnia-tarasu         powierzchnia-tarasu
# 41                            loggia                      loggia
# 42              powierzchnia-ogrodka                           0
# 43                          typ-domu                           0
# 44                  dodatkowe-koszty                           0
# 45                 typ-nieruchomosci                           0
# 46               powierzchnia-loggii                           0
# 47                       pow-dzialki                           0
# 48                              dach                           0
# 49                                 0                           0
#
#            pd_otodom_mieszkania            pd_trojmiasto
# 0                         adres                    nazwa
# 1                          imie                    tresc
# 2           biuro_nieruchomosci                     cena
# 3                         tresc             liczba-pokoi
# 4                  cena_za_metr                   pietro
# 5                          cena               rok-budowy
# 6                        oferta   nr-licencji-posrednika
# 7                  liczba_zdjec     rodzaj-nieruchomosci
# 8                          data                nr-oferty
# 9             data_aktualizacji  liczba-pieter-w-budynku
# 10                 numer_otodom             powierzchnia
# 11                       balkon           typ-ogrzewania
# 12                      piwnica         numer-ogloszenia
# 13            oddzielna kuchnia         data-wyroznienia
# 14                 Powierzchnia        data-wprowadzenia
# 15                 Liczba pokoi             aktualizacja
# 16                        Rynek               wyswietlen
# 17              Rodzaj zabudowy     wyswietlen-na-liscie
# 18                       Piętro     dodatkowe-informacje
# 19                Liczba pięter                    adres
# 20             Materiał budynku                  zdjecie
# 21                         Okna              dostepne-od
# 22                   Ogrzewanie     powierzchnia-dzialki
# 23                   Rok budowy               ulica-i-nr
# 24             Stan wykończenia                   miasto
# 25                       Czynsz                        0
# 26              Forma własności                        0
# 27                  Dostępne od                        0
# 28            telewizja kablowa                        0
# 29                     internet                        0
# 30                      telefon                        0
# 31              system alarmowy                        0
# 32  drzwi / okna antywłamaniowe                        0
# 33              teren zamknięty                        0
# 34           domofon / wideofon                        0
# 35         monitoring / ochrona                        0
# 36        rolety antywłamaniowe                        0
# 37                 klimatyzacja                        0
# 38     garaż/miejsce parkingowe                        0
# 39                        winda                        0
# 40                        taras                        0
# 41                pom. użytkowe                        0
# 42                     zmywarka                        0
# 43                      lodówka                        0
# 44                        meble                        0
# 45                    piekarnik                        0
# 46                     kuchenka                        0
# 47                       pralka                        0
# 48                      ogródek                        0
# 49                 dwupoziomowe                        0

# %%
df_porownanie = df_porownanie[['pd_trojmiasto','pd_morizon_sopot','pd_gratka_mieszkania_sopot','pd_gratka_mieszkania_gdansk','pd_gratka_mieszkania_gdynia','pd_morizon_gdynia','pd_morizon_gdansk','pd_otodom_mieszkania']]

# %%
df_porownanie
# Out:
#               pd_trojmiasto            pd_morizon_sopot  \
# 0                     nazwa                      miasto
# 1                     tresc                   dzielnica
# 2                      cena                       ulica
# 3              liczba-pokoi                powierzchnia
# 4                    pietro                     cena_m2
# 5                rok-budowy                      pokoje
# 6    nr-licencji-posrednika       powierzchnia-uzytkowa
# 7      rodzaj-nieruchomosci                      pietro
# 8                 nr-oferty               liczba-pieter
# 9   liczba-pieter-w-budynku  liczba-poziomow-mieszkania
# 10             powierzchnia                      balkon
# 11           typ-ogrzewania                       rynek
# 12         numer-ogloszenia                 dostepne-od
# 13         data-wyroznienia                      kredyt
# 14        data-wprowadzenia                numer-oferty
# 15             aktualizacja              zaktualizowano
# 16               wyswietlen                opublikowano
# 17     wyswietlen-na-liscie                  rok-budowy
# 18     dodatkowe-informacje                       tresc
# 19                    adres             liczba-sypialni
# 20                  zdjecie                       taras
# 21              dostepne-od                rodzaj-umowy
# 22     powierzchnia-dzialki            wysokosc-wnetrza
# 23               ulica-i-nr                  typ-kuchni
# 24                   miasto             liczba-lazienek
# 25                        0       powierzchnia-lazienki
# 26                        0           czy-lazienka-z-wc
# 27                        0        powierzchnia-balkonu
# 28                        0             forma-wlasnosci
# 29                        0                 typ-budynku
# 30                        0          material-budowlany
# 31                        0                stan-budynku
# 32                        0                    na-biuro
# 33                        0          stan-nieruchomosci
# 34                        0          cena-do-negocjacji
# 35                        0            dodatkowe-koszty
# 36                        0           typ-nieruchomosci
# 37                        0                    typ-domu
# 38                        0                        dach
# 39                        0            stolarka-okienna
# 40                        0         powierzchnia-tarasu
# 41                        0                      loggia
# 42                        0                           0
# 43                        0                           0
# 44                        0                           0
# 45                        0                           0
# 46                        0                           0
# 47                        0                           0
# 48                        0                           0
# 49                        0                           0
#
#              pd_gratka_mieszkania_sopot          pd_gratka_mieszkania_gdansk  \
# 0                                  cena                                 cena
# 1                           cena_waluta                          cena_waluta
# 2                          cena_za_metr                         cena_za_metr
# 3                         id_ogloszenia                        id_ogloszenia
# 4                                 tresc                                tresc
# 5                               zdjecie                              zdjecie
# 6                           lokalizacja                          lokalizacja
# 7                                 adres                                adres
# 8                     powierzchnia-w-m2                    powierzchnia-w-m2
# 9                          powierzchnia                         powierzchnia
# 10                         liczba-pokoi                         liczba-pokoi
# 11                         liczba_pokoi                         liczba_pokoi
# 12                               pietro                               pietro
# 13                      forma-wlasnosci                      forma-wlasnosci
# 14                           rok-budowy                         typ-zabudowy
# 15                           rok_budowy                      rodzaj_zabudowy
# 16                         typ-zabudowy                             typ_domu
# 17                      rodzaj_zabudowy                     material-budynku
# 18                             typ_domu              liczba-pieter-w-budynku
# 19              liczba-pieter-w-budynku                liczba_pieter_budynku
# 20                liczba_pieter_budynku                   miejsce-parkingowe
# 21                   miejsce-parkingowe                         forma-kuchni
# 22                   numer-referencyjny                              kuchnia
# 23                    data_aktualizacji                                 okna
# 24                    typ_nieruchomosci                     nazwa-inwestycji
# 25                     material-budynku                   numer-referencyjny
# 26                         forma-kuchni           forma-wyposazenie-lazienki
# 27                              kuchnia    usytuowanie-wzgledem-stron-swiata
# 28  oplaty-czynsz-administracyjny-media                    data_aktualizacji
# 29                          komunikacja                    typ_nieruchomosci
# 30                      zdrowie-i-uroda  oplaty-czynsz-administracyjny-media
# 31                             edukacja                           rok-budowy
# 32                            pozostale                           rok_budowy
# 33                                 stan                                 stan
# 34                          wykonczenie                          wykonczenie
# 35               powierzchnia-dodatkowa           liczba-miejsc-parkingowych
# 36                                 okna                      stan-instalacji
# 37                      stan-instalacji                        stan-lazienki
# 38                        stan-lazienki                             glosnosc
# 39                             glosnosc                        dostepnosc-od
# 40           forma-wyposazenie-lazienki                        data_dostepne
# 41                     nazwa-inwestycji           czy-mieszkanie-ma-lazienke
# 42    usytuowanie-wzgledem-stron-swiata               powierzchnia-dodatkowa
# 43           czy-mieszkanie-ma-lazienke                          komunikacja
# 44                                    0                      zdrowie-i-uroda
# 45                                    0                             edukacja
# 46                                    0                            pozostale
# 47                                    0                                    0
# 48                                    0                                    0
# 49                                    0                                    0
#
#             pd_gratka_mieszkania_gdynia                 pd_morizon_gdynia  \
# 0                                  cena                            miasto
# 1                           cena_waluta                         dzielnica
# 2                          cena_za_metr                             ulica
# 3                         id_ogloszenia                      powierzchnia
# 4                                 tresc                           cena_m2
# 5                               zdjecie                            pokoje
# 6                           lokalizacja             powierzchnia-uzytkowa
# 7                                 adres                            pietro
# 8   oplaty-czynsz-administracyjny-media                     liczba-pieter
# 9                     powierzchnia-w-m2                        typ-kuchni
# 10                         powierzchnia                 czy-lazienka-z-wc
# 11                         liczba-pokoi                            balkon
# 12                         liczba_pokoi              powierzchnia-balkonu
# 13                               pietro                             taras
# 14                      forma-wlasnosci                             rynek
# 15                                 stan                   forma-wlasnosci
# 16                          wykonczenie                          na-biuro
# 17                           rok-budowy                            kredyt
# 18                           rok_budowy                      numer-oferty
# 19                         typ-zabudowy                    zaktualizowano
# 20                      rodzaj_zabudowy                      opublikowano
# 21                             typ_domu                        rok-budowy
# 22                     material-budynku                      stan-budynku
# 23              liczba-pieter-w-budynku                             tresc
# 24                liczba_pieter_budynku        liczba-poziomow-mieszkania
# 25                   miejsce-parkingowe                   liczba-sypialni
# 26           liczba-miejsc-parkingowych                       dostepne-od
# 27                      stan-instalacji                       typ-budynku
# 28                         forma-kuchni                material-budowlany
# 29                              kuchnia                      rodzaj-umowy
# 30                        stan-lazienki                stan-nieruchomosci
# 31                                 okna                  stolarka-okienna
# 32                             glosnosc  czy-przy-mieszkaniu-jest-ogrodek
# 33                        dostepnosc-od                cena-do-negocjacji
# 34                        data_dostepne                  wysokosc-wnetrza
# 35           czy-mieszkanie-ma-lazienke                   liczba-lazienek
# 36           forma-wyposazenie-lazienki             powierzchnia-lazienki
# 37               powierzchnia-dodatkowa                        na-zamiane
# 38    usytuowanie-wzgledem-stron-swiata                         deweloper
# 39                          komunikacja                        inwestycja
# 40                      zdrowie-i-uroda               powierzchnia-tarasu
# 41                             edukacja                            loggia
# 42                            pozostale              powierzchnia-ogrodka
# 43                    data_aktualizacji                          typ-domu
# 44                    typ_nieruchomosci                  dodatkowe-koszty
# 45                   numer-referencyjny                 typ-nieruchomosci
# 46                     nazwa-inwestycji               powierzchnia-loggii
# 47                                    0                       pow-dzialki
# 48                                    0                              dach
# 49                                    0                                 0
#
#                    pd_morizon_gdansk         pd_otodom_mieszkania
# 0                             miasto                        adres
# 1                          dzielnica                         imie
# 2                              ulica          biuro_nieruchomosci
# 3                       powierzchnia                        tresc
# 4                            cena_m2                 cena_za_metr
# 5                             pokoje                         cena
# 6              powierzchnia-uzytkowa                       oferta
# 7                             pietro                 liczba_zdjec
# 8                      liczba-pieter                         data
# 9                         typ-kuchni            data_aktualizacji
# 10                            balkon                 numer_otodom
# 11              powierzchnia-balkonu                       balkon
# 12                             taras                      piwnica
# 13                             rynek            oddzielna kuchnia
# 14                       dostepne-od                 Powierzchnia
# 15                   forma-wlasnosci                 Liczba pokoi
# 16                          na-biuro                        Rynek
# 17                            kredyt              Rodzaj zabudowy
# 18                      numer-oferty                       Piętro
# 19                    zaktualizowano                Liczba pięter
# 20                      opublikowano             Materiał budynku
# 21                        rok-budowy                         Okna
# 22                      stan-budynku                   Ogrzewanie
# 23                             tresc                   Rok budowy
# 24                         deweloper             Stan wykończenia
# 25                        inwestycja                       Czynsz
# 26                stan-nieruchomosci              Forma własności
# 27                   liczba-lazienek                  Dostępne od
# 28                       typ-budynku            telewizja kablowa
# 29                  wysokosc-wnetrza                     internet
# 30        liczba-poziomow-mieszkania                      telefon
# 31                 czy-lazienka-z-wc              system alarmowy
# 32                cena-do-negocjacji  drzwi / okna antywłamaniowe
# 33                material-budowlany              teren zamknięty
# 34                   liczba-sypialni           domofon / wideofon
# 35                            loggia         monitoring / ochrona
# 36                      rodzaj-umowy        rolety antywłamaniowe
# 37             powierzchnia-lazienki                 klimatyzacja
# 38              powierzchnia-ogrodka     garaż/miejsce parkingowe
# 39                        na-zamiane                        winda
# 40                  stolarka-okienna                        taras
# 41  czy-przy-mieszkaniu-jest-ogrodek                pom. użytkowe
# 42                          typ-domu                     zmywarka
# 43                  dodatkowe-koszty                      lodówka
# 44               powierzchnia-loggii                        meble
# 45                       lokalizacja                    piekarnik
# 46               powierzchnia-tarasu                     kuchenka
# 47                              dach                       pralka
# 48                       pow-dzialki                      ogródek
# 49                 typ-nieruchomosci                 dwupoziomowe
